# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=0)
x = [[1,2,3],
     [11,12,13]]
y = [0,1]
clf.fit(x,y) #setting model;to make the model learn from training data
RandomForestClassifier(random_state=0)
# Out:
# RandomForestClassifier(random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier #compare trained data with new data; predictions based on trained model
x=[[1,2,3],[11,12,13]]
y=[0,1]

clf=RandomForestClassifier()
clf.fit(x,y)

predicted_training = clf.predict(x)
print("Prdicted classes for training data",predicted_training)

predicted_new =clf.predict([[21,22,23],[14,15,16]])
print("Predicted class for new data",predicted_new)
# Out:
# Prdicted classes for training data [0 1]
# Predicted class for new data [1 1]

# %%
from sklearn.preprocessing import StandardScaler #transform is for measuring; to apply a learned transformation like scaling,encoding,dimensional reduction to new data.
x=[[0,15],
   [1,-10]]
scaler = StandardScaler()
scaled_x= scaler.fit(x).transform(x)

print("Scaled data")
print(scaled_x)
# Out:
# Scaled data
# [[-1.  1.]
#  [ 1. -1.]]

# %% [markdown]
# LINEAR REGRESSION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

df=pd.read_csv('houseprice1.csv')
df
# Out:
#    Sl no    Area     Price
# 0    1.0  2600.0  550000.0
# 1    2.0  3000.0  565000.0
# 2    3.0  3200.0  610000.0
# 3    4.0  3600.0  680000.0
# 4    5.0  4000.0  725000.0
# 5    NaN     NaN       NaN

# %%
df.dropna()
df
# Out:
#    Sl no    Area     Price
# 0    1.0  2600.0  550000.0
# 1    2.0  3000.0  565000.0
# 2    3.0  3200.0  610000.0
# 3    4.0  3600.0  680000.0
# 4    5.0  4000.0  725000.0
# 5    NaN     NaN       NaN

# %%
df.fillna(0)
df
# Out:
#    Sl no    Area     Price
# 0    1.0  2600.0  550000.0
# 1    2.0  3000.0  565000.0
# 2    3.0  3200.0  610000.0
# 3    4.0  3600.0  680000.0
# 4    5.0  4000.0  725000.0
# 5    NaN     NaN       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sl no   5 non-null      float64
#  1   Area    5 non-null      float64
#  2   Price   5 non-null      float64
# dtypes: float64(3)
# memory usage: 276.0 bytes

# %%
plt.xlabel('Area')
plt.ylabel('Price')
plt.scatter(df.Area,df.Price,color='green',marker='+')

# %%
new_df = df.drop('Price',axis='columns')
new_df
# Out:
#    Sl no    Area
# 0    1.0  2600.0
# 1    2.0  3000.0
# 2    3.0  3200.0
# 3    4.0  3600.0
# 4    5.0  4000.0
# 5    NaN     NaN

# %%
price = df.Price
price
# Out:
# 0    550000.0
# 1    565000.0
# 2    610000.0
# 3    680000.0
# 4    725000.0
# 5         NaN
# Name: Price, dtype: float64

# %%
reg = linear_model.LinearRegression()
reg.fit(new_df1,price)
# Out:
# LinearRegression()

# %%
reg.predict([[3200]])
# Out:
# C:\Users\M Shreya Reddy\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([615136.98630137])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
3200*135.78767123+180616.43835616432
# Out:
# 615136.9862921643

# %%
import pandas as pd
area_df=pd.read_csv('areas.csv')
area_df
# Out:
#    Area
# 0  2500
# 1  3000
# 2  3500

# %%
p=reg.predict(area_df)
p
# Out:
# array([520085.61643836, 587979.45205479, 655873.28767123])

# %%
area_df['Price']=p
area_df
# Out:
#    Area          Price
# 0  2500  520085.616438
# 1  3000  587979.452055
# 2  3500  655873.287671

# %%
area_df.to_csv("prediction.csv")

# %%
df1=pd.read_csv('canada_per_capita_income.csv')
df1
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
new_df3 = df1.drop('year',axis='columns')
new_df3
# Out:
#     per capita income (US$)
# 0               3399.299037
# 1               3768.297935
# 2               4251.175484
# 3               4804.463248
# 4               5576.514583
# 5               5998.144346
# 6               7062.131392
# 7               7100.126170
# 8               7247.967035
# 9               7602.912681
# 10              8355.968120
# 11              9434.390652
# 12              9619.438377
# 13             10416.536590
# 14             10790.328720
# 15             11018.955850
# 16             11482.891530
# 17             12974.806620
# 18             15080.283450
# 19             16426.725480
# 20             16838.673200
# 21             17266.097690
# 22             16412.083090
# 23             15875.586730
# 24             15755.820270
# 25             16369.317250
# 26             16699.826680
# 27             17310.757750
# 28             16622.671870
# 29             17581.024140
# 30             18987.382410
# 31             18601.397240
# ...

# %%
year=df1[['year']]
year
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
new_df4=df1[['per capita income (US$)']]
new_df4
# Out:
#     per capita income (US$)
# 0               3399.299037
# 1               3768.297935
# 2               4251.175484
# 3               4804.463248
# 4               5576.514583
# 5               5998.144346
# 6               7062.131392
# 7               7100.126170
# 8               7247.967035
# 9               7602.912681
# 10              8355.968120
# 11              9434.390652
# 12              9619.438377
# 13             10416.536590
# 14             10790.328720
# 15             11018.955850
# 16             11482.891530
# 17             12974.806620
# 18             15080.283450
# 19             16426.725480
# 20             16838.673200
# 21             17266.097690
# 22             16412.083090
# 23             15875.586730
# 24             15755.820270
# 25             16369.317250
# 26             16699.826680
# 27             17310.757750
# 28             16622.671870
# 29             17581.024140
# 30             18987.382410
# 31             18601.397240
# ...

# %%
reg2 = linear_model.LinearRegression()
reg2.fit(year,new_df4)
# Out:
# LinearRegression()

# %%
reg2 = linear_model.LinearRegression()
reg2.fit(X, y)

year_2020 = reg2.predict([[2020]])
year_2020
# Out:
# C:\Users\M Shreya Reddy\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
